# %% [markdown]
# # Practica 5

# %%
import matplotlib.pyplot as plt

# Datos del primer conjunto
data1 = {
    'V': [0.430, 0.435, 0.440, 0.445, 0.450, 0.455, 0.460, 0.465, 0.470, 0.475, 0.480, 
          0.485, 0.490, 0.495, 0.500, 0.505, 0.510, 0.515, 0.520, 0.525],
    'uA': [0.118, 0.125, 0.148, 0.175, 0.201, 0.236, 0.271, 0.322, 0.361, 0.427, 0.478,
           0.546, 0.610, 0.712, 0.791, 0.868, 0.968, 1.080, 1.201, 1.329]
}

# Datos del segundo conjunto (invertidos)
data2 = {
    'V': [-5.108, -5.098, -5.088, -5.078, -5.068, -5.061],
    'uA': [-0.0005, -0.0005, -0.0006, -0.0004, -0.0005, -0.0005]
}

# Graficar datos del primer conjunto
plt.figure(figsize=(8, 6))
plt.scatter(data1['V'], data1['uA'], label='Datos 1')

# Graficar datos del segundo conjunto
plt.scatter(data2['V'], data2['uA'], label='Datos 2')

plt.xlabel('Voltaje (V)')
plt.ylabel('Corriente ($\mu_{\mathrm{A}}$) [mADC]')
plt.title('Gráfico de Corriente vs. Voltaje')

plt.legend()
plt.grid(True)
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos del primer conjunto
data1 = {
    'V': [0.430, 0.435, 0.440, 0.445, 0.450, 0.455, 0.460, 0.465, 0.470, 0.475, 0.480, 
          0.485, 0.490, 0.495, 0.500, 0.505, 0.510, 0.515, 0.520, 0.525],
    'uA': [0.118, 0.125, 0.148, 0.175, 0.201, 0.236, 0.271, 0.322, 0.361, 0.427, 0.478,
           0.546, 0.610, 0.712, 0.791, 0.868, 0.968, 1.080, 1.201, 1.329]
}

# Datos del segundo conjunto (invertidos)
data2 = {
    'V': [-5.108, -5.098, -5.088, -5.078, -5.068, -5.061],
    'uA': [-0.0005, -0.0005, -0.0006, -0.0004, -0.0005, -0.0005]
}

# Graficar datos del primer conjunto
plt.figure(figsize=(15, 15))
plt.scatter(data1['V'], data1['uA'], label='Datos 1')

# Graficar datos del segundo conjunto
plt.scatter(data2['V'], data2['uA'], label='Datos 2')

# Establecer límites de los ejes x e y
plt.xlim(min(data1['V']) - 0.1, max(data1['V']) + 0.1)
plt.ylim(min(data1['uA']) - 0.1, max(data1['uA']) + 0.1)

plt.xlabel('Voltaje (V)')
plt.ylabel('Corriente ($\mu_{\mathrm{A}}$) [mADC]')
plt.title('Gráfico de Corriente vs. Voltaje')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Vemos que se cumple el comportamiento deseado, pero los datos de la segunda tabla (la zona invertida) no se alcanzan del todo bien. Es cierto que se puede modificar el tamaño de la rejilla o del plano xy en los codigos anteriores pero como otra siguerencia a continuacion se presentan dos codigos que grafican cada tabla de datos por separado.

# %% [markdown]
# ## Grafica para la primera tabla de datos

# %%
import matplotlib.pyplot as plt

# Datos del primer conjunto
data1 = {
    'V': [0.430, 0.435, 0.440, 0.445, 0.450, 0.455, 0.460, 0.465, 0.470, 0.475, 0.480, 
          0.485, 0.490, 0.495, 0.500, 0.505, 0.510, 0.515, 0.520, 0.525],
    'uA': [0.118, 0.125, 0.148, 0.175, 0.201, 0.236, 0.271, 0.322, 0.361, 0.427, 0.478,
           0.546, 0.610, 0.712, 0.791, 0.868, 0.968, 1.080, 1.201, 1.329]
}

# Graficar datos del primer conjunto
plt.figure(figsize=(8, 6))
plt.scatter(data1['V'], data1['uA'], label='Datos 1')

plt.xlabel('Voltaje (V)')
plt.ylabel('Corriente ($\mu_{\mathrm{A}}$) [mADC]')
plt.title('Gráfico de Corriente vs. Voltaje (Datos 1)')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Grafica para la segunda tabla de datos (la que llamamos "datos invertidos")

# %%
import matplotlib.pyplot as plt

# Datos del segundo conjunto (invertidos)
data2 = {
    'V': [-5.108, -5.098, -5.088, -5.078, -5.068, -5.061],
    'uA': [-0.0005, -0.0005, -0.0006, -0.0004, -0.0005, -0.0005]
}

# Graficar datos del segundo conjunto
plt.figure(figsize=(8, 6))
plt.scatter(data2['V'], data2['uA'], label='Datos 2')

plt.xlabel('Voltaje (V)')
plt.ylabel('Corriente ($\mu_{\mathrm{A}}$) [mADC]')
plt.title('Gráfico de Corriente vs. Voltaje (Datos 2)')

plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos del segundo conjunto (invertidos)
data2 = {
    'V': [-5.108, -5.098, -5.088, -5.078, -5.068, -5.061],
    'uA': [-0.0005, -0.0005, -0.0006, -0.0004, -0.0005, -0.0005]
}

# Graficar datos del segundo conjunto con límites ampliados
plt.figure(figsize=(8, 6))
plt.scatter(data2['V'], data2['uA'], label='Datos 2')

# Establecer límites de los ejes x e y más amplios
plt.xlim(min(data2['V']) - 1, max(data2['V']) + 1)
plt.ylim(min(data2['uA']) - 0.001, max(data2['uA']) + 0.001)

plt.xlabel('Voltaje (V)')
plt.ylabel('Corriente ($\mu_{\mathrm{A}}$) [mADC]')
plt.title('Gráfico de Corriente vs. Voltaje (Datos 2) - Vista Ampliada')

plt.legend()
plt.grid(True)
plt.show()
